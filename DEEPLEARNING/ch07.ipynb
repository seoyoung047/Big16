# %% [markdown]
# # **20230614**

# %% [markdown]
# ## 7장 퍼셉트론과 인공지능의 시작

# %% [markdown]
# ### 01 인공지능의 시작을 알린 퍼셉트론

# %%
from IPython.display import Image

# %%
Image('./ch07_신경망.png')

# %%
Image('./ch07_로지스틱회귀모델.png')

# %% [markdown]
# ### 02 퍼셉트론의 과제

# %%
Image('./ch07_퍼셉트론의과제.png')

# %% [markdown]
# ### 03 XOR(exlusice OR) 문제

# %%
Image('./ch07_XOR문제.png')

# %% [markdown]
# - 다층 퍼셉트론과 오차 역전파
#
# : 이 두가지 방법으로 XOR 문제 해결
