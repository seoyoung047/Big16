# %% [markdown]
# # **20230614**

# %% [markdown]
# ## 9장 오차 역전파에서 딥러닝으로

# %% [markdown]
# ### 01 오차 역전파
# : 역순으로 학습하며 오차를 수정
#
# - 원래 학습 : ${f1(f2(f3(w_1)))}'$
#
# - 오차 역전파 : ${f3(f2(f1(w_3)))}'$

# %% [markdown]
# ### 02 활성화 함수와 고급 경사 하강법

# %%
from IPython.display import Image
Image('./ch09_경사하강법.png')

# %%
Image('./ch09_활성화함수.png')

# %% [markdown]
# - 시그모이드 함수 미분시 기울기(데이터) 소실(gradient banishing) 있음 $\Rightarrow$ 불필요한 데이터 소실시킬 때 사용 (LSTM,LongShortTermMemory)

# %% [markdown]
# ### 03 학습 속도와 정확도 문제를 해결하는 고급 경사 하강법

# %% [markdown]
# #### 확률적 경사 하강법(SGD, Stochastic Gradient Descent)
#
#
# - 랜덤하게 일부 데이터를 가져와 사용 = **미니 배치**
#
# - 기존 경사하강법에 비해 속도가 빠르고 최적 해(Global Minimum)에 근사한 값을 찾아냄
#
#
# -> 일부 데이터 가져오는 것이므로 기존 방법보다 성능이 좋지 않을 확률 있음^^

# %% [markdown]
# #### 모멘텀(momentum)
#
# : 관성, 탄력, 가속도
#
# - ***모멘텀 SGB*** : 이전 이동값을 고려해 일정 비율만큼 다음 값을 결정 => 관성효과
#
# - 기울기가 작아질수록 => 최적해에 가까워질수록 수정값을 줄임

# %% [markdown]
# #### 딥러닝에서의 고급 경사 하강법
#
# - 주로 ***아담(adam)*** 사용
#
# => optimizers에 사용하면됨

# %%
Image('./ch09_고급 경사하강법.png')
