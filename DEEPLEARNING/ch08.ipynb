# %% [markdown]
# # **20230614**

# %% [markdown]
# ## 8장 다층 퍼셉트론

# %% [markdown]
# ### 01 다층 퍼셉트론의 등장
#
#
# - 다층 = 딥러닝

# %%
from IPython.display import Image

# %%
Image('./ch08_다층퍼셉트론.png')

# %% [markdown]
# ### 02 다층 퍼셉트론의 설계
