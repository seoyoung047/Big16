# %% [markdown]
# # **20230615**

# %% [markdown]
# ## 10장 딥러닝 모델 설계하기
#
# - TensorFlow Library
#
#     - Tensor :  다차원 배열 -> 신경망 구축 - 세부설정필요
#
#     - Keras : Tensor보다 간편 - 신경망 조립식 구축

# %% [markdown]
# ### 01 모델의 정의

# %%
# 폐암 수술 환자의 생존율 예측하기

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import pandas as pd
import numpy as np

Data_set = pd.read_csv('../data/ThoraricSurgery3.csv', header=None)

X = Data_set.iloc[:, 0:16]
y = Data_set.iloc[:, 16]

model = Sequential()
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy'
              , optimizer='adam'
              ,metrics=['accuracy']
              )


history = model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 1s 2ms/step - loss: 1.8522 - accuracy: 0.8489
# Epoch 2/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.8255
# Epoch 3/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.8468
# Epoch 4/5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4346 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8511

# %% [markdown]
# ### 02 입력층, 은닉층, 출력층

# %%
model = Sequential()
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### 03 모델 컴파일

# %%
from IPython.display import Image
Image('./ch10_loss_오차함수.png')

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# ### 04 모델 실행하기

# %%
history = model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8511
# Epoch 2/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.8511
# Epoch 3/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4234 - accuracy: 0.8511
# Epoch 4/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4238 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8511
